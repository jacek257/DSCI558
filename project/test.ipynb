# %%
import json

# %%
file = 'opgg.json'

# %%
with open(file) as data_file:    
    data = json.load(data_file)

for entry in data:
    print('=====================')
    print(json.dumps(entry, indent=2))
# Out:
# ...
# {
#   "Syndra": {
#     "wins": 47,
#     "losts": 42,
#     "win rate": 0.53,
#     "KDA": 2.61,
#     "kills": 4.2,
#     "deaths": 4.0,
#     "assists": 6.2,
#     "Gold": 11088,
#     "cs": 219.6,
#     "cs/min": 8.3,
#     "Max Kills": 14,
#     "Max Deaths": 11,
#     "Average Damage Dealt": 137491,
#     "Average Damage Taken": 13072,
#     "Double Kill": 25
#   },
#   "Lucian": {
#     "wins": 30,
#     "losts": 31,
#     "win rate": 0.49,
#     "KDA": 2.5,
#     "kills": 4.7,
#     "deaths": 3.9,
#     "assists": 5.1,
#     "Gold": 11174,
#     "cs": 217.9,
#     "cs/min": 8.5,
#     "Max Kills": 13,
#     "Max Deaths": 10,
#     "Average Damage Dealt": 143895,
#     "Average Damage Taken": 15194,
#     "Double Kill": 28
#   },
#   "Zoe": {
#     "wins": 29,
#     "losts": 24,
#     "win rate": 0.55,
#     "KDA": 3.19,
#     "kills": 4.9,
#     "deaths": 3.5,
#     "assists": 6.1,
#     "Gold": 10493,
#     "cs": 193.5,
#     "cs/min": 7.7,
#     "Max Kills": 14,
# ...
